# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode
from pyspark.sql.functions import split  

spark = SparkSession \
    .builder \
    .appName("StructuredNetworkWordCount") \
    .getOrCreate()
# Out:
# 24/08/01 14:29:46 WARN Utils: Your hostname, LPYTHON-101 resolves to a loopback address: 127.0.1.1; using 172.22.114.204 instead (on interface eno1)
# 24/08/01 14:29:46 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/08/01 14:29:47 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Create DataFrame representing the stream of input lines from connection to localhost:9999
lines = spark \
    .readStream \
    .format("socket") \
    .option("host", "localhost") \
    .option("port", 6662) \
    .load()
# Out:
# 24/08/01 14:29:50 WARN TextSocketSourceProvider: The socket source should not be used for production applications! It does not support recovery.

# %%
# Split the lines into words
words = lines.select(
   explode(
       split(lines.value, " ")
   ).alias("word")
)

# Generate running word count
wordCounts = words.groupBy("word").count()
query = wordCounts \
    .writeStream \
    .outputMode('complete') \
    .format("console") \
    .start()
query.awaitTermination()
# Out:
# 24/08/01 14:29:53 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-194ddf58-585f-401f-ac5a-7f7ab39b0072. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 24/08/01 14:29:53 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +----+-----+
# |word|count|
# +----+-----+
# +----+-----+
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +---------+-----+
# |     word|count|
# +---------+-----+
# |bookshelf|    1|
# | randomly|    2|
# |   harder|    1|
# | cautious|    1|
# |      few|    9|
# |    still|   13|
# |   outfit|    1|
# |involving|    1|
# |    those|    5|
# |   travel|    1|
# |  isbn-13|    1|
# |  flashed|    2|
# |     some|   10|
# |  clawing|    1|
# | slightly|    4|
# |  include|    1|
# | sneaking|    1|
# |   nights|    1|
# |  painted|    2|
# |   taking|    1|
# +---------+-----+
# only showing top 20 rows
# 24/08/01 14:30:03 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +----------+-----+
# |      word|count|
# +----------+-----+
# | bookshelf|    1|
# |       art|    3|
# |    harder|    1|
# |  cautious|    1|
# |     still|   21|
# |    outfit|    1|
# |     those|    6|
# |   isbn-13|    1|
# |   flashed|    3|
# |      hope|    2|
# |  randomly|    3|
# |strawberry|    3|
# |   skidded|    1|
# |       few|   10|
# | involving|    1|
# | traveling|    1|
# |    travel|    3|
# |      some|   23|
# |   clawing|    1|
# |  slightly|    6|
# +----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +----------+-----+
# |      word|count|
# +----------+-----+
# | bookshelf|    1|
# |       art|    3|
# |    harder|    2|
# |  cautious|    1|
# |     still|   24|
# |    outfit|    1|
# |     those|    9|
# |   isbn-13|    1|
# |   flashed|    4|
# |   embrace|    1|
# |      hope|    6|
# |  randomly|    3|
# |strawberry|    3|
# |   skidded|    1|
# |       few|   12|
# |       ...|    8|
# | involving|    1|
# | traveling|    1|
# |    travel|    3|
# |      some|   38|
# +----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +----------+-----+
# |      word|count|
# +----------+-----+
# | bookshelf|    1|
# |       art|    3|
# |    harder|    2|
# |  cautious|    1|
# |     still|   28|
# |    outfit|    1|
# |     those|   10|
# |   isbn-13|    1|
# |   flashed|    5|
# |   embrace|    1|
# |      hope|    6|
# |  randomly|    3|
# |strawberry|    3|
# |   skidded|    1|
# |       few|   12|
# |       ...|   17|
# | involving|    1|
# | traveling|    1|
# |    travel|    3|
# |      some|   42|
# +----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +----------+-----+
# |      word|count|
# +----------+-----+
# | bookshelf|    1|
# |       art|    3|
# |    harder|    2|
# |  cautious|    1|
# |     still|   31|
# |    outfit|    1|
# |     those|   12|
# |   isbn-13|    1|
# |   flashed|    5|
# |   embrace|    1|
# |      hope|    6|
# |  randomly|    3|
# |strawberry|    3|
# |   skidded|    1|
# |       few|   13|
# |       ...|   20|
# | involving|    1|
# | traveling|    1|
# |    travel|    3|
# |      some|   45|
# +----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +----------+-----+
# |      word|count|
# +----------+-----+
# | bookshelf|    1|
# |       art|    3|
# |    harder|    2|
# |  cautious|    1|
# |     still|   34|
# |    outfit|    1|
# |     those|   14|
# |   isbn-13|    1|
# |   flashed|    5|
# |   embrace|    1|
# | standards|    1|
# |      hope|    6|
# |  randomly|    3|
# |strawberry|    3|
# |   skidded|    1|
# |       few|   14|
# |       ...|   22|
# | involving|    2|
# | traveling|    1|
# |    travel|    3|
# +----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 7
# -------------------------------------------
# +----------+-----+
# |      word|count|
# +----------+-----+
# | bookshelf|    1|
# |       art|    3|
# |    harder|    4|
# |  cautious|    1|
# |     still|   35|
# |    outfit|    1|
# |     those|   14|
# |   isbn-13|    1|
# |   flashed|    5|
# |   embrace|    1|
# | standards|    1|
# |      hope|    7|
# |  randomly|    3|
# |strawberry|    3|
# |   skidded|    2|
# |       few|   14|
# |       ...|   22|
# | involving|    2|
# | traveling|    1|
# |    travel|    3|
# +----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 8
# -------------------------------------------
# +----------+-----+
# |      word|count|
# +----------+-----+
# | bookshelf|    1|
# |       art|    3|
# |    harder|    4|
# |  cautious|    1|
# |     still|   45|
# |    outfit|    1|
# |     those|   15|
# |   isbn-13|    1|
# |   flashed|    5|
# |   embrace|    1|
# | standards|    1|
# |      hope|    8|
# |  randomly|    3|
# |strawberry|    3|
# |   skidded|    2|
# |       few|   20|
# |       ...|   22|
# | involving|    2|
# | traveling|    1|
# |    travel|    4|
# +----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 9
# -------------------------------------------
# +----------+-----+
# |      word|count|
# +----------+-----+
# | bookshelf|    1|
# |       art|    3|
# |    ambrin|    3|
# |    harder|    4|
# |  cautious|    1|
# |   jewelry|    2|
# |     still|   52|
# |    outfit|    1|
# |     those|   19|
# | arguments|    1|
# |   isbn-13|    1|
# |   flashed|    6|
# |   embrace|    1|
# | standards|    1|
# |      hope|    8|
# |     ruben|    3|
# |  randomly|    3|
# |strawberry|    3|
# |   skidded|    2|
# |       few|   22|
# +----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 10
# -------------------------------------------
# +---------+-----+
# |     word|count|
# +---------+-----+
# |bookshelf|    1|
# |   harder|    4|
# |    still|   64|
# |   outfit|    1|
# |arguments|    1|
# |standards|    2|
# |     hope|    8|
# |    ruben|    3|
# |      ...|   23|
# |   bazaar|    2|
# |traveling|    2|
# |     some|   67|
# |      art|    3|
# |   ambrin|    7|
# |  reddish|    1|
# | cautious|    1|
# |  jewelry|    2|
# |    those|   19|
# |  isbn-13|    1|
# |  flashed|    6|
# +---------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 11
# -------------------------------------------
# +---------+-----+
# |     word|count|
# +---------+-----+
# |bookshelf|    1|
# |   harder|    4|
# |    still|   74|
# |   outfit|    1|
# |arguments|    2|
# |standards|    2|
# |     hope|    9|
# |    ruben|    5|
# |    trail|    2|
# |      ...|   24|
# |   bazaar|    2|
# |traveling|    2|
# |     some|   78|
# | tortured|    1|
# |      art|    3|
# |   ambrin|    8|
# |  reddish|    1|
# | cautious|    1|
# |  jewelry|    2|
# |    those|   20|
# +---------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 12
# -------------------------------------------
# +---------+-----+
# |     word|count|
# +---------+-----+
# |bookshelf|    1|
# |   harder|    4|
# |    still|   84|
# |   outfit|    1|
# |arguments|    2|
# |standards|    2|
# |     hope|    9|
# |    ruben|    5|
# |    trail|    2|
# |      ...|   24|
# |   bazaar|    2|
# |traveling|    3|
# |     some|   87|
# | tortured|    1|
# |  tresses|    1|
# |      art|    3|
# |     guts|    1|
# |   ambrin|    8|
# |  reddish|    1|
# | cautious|    1|
# +---------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 13
# -------------------------------------------
# +---------+-----+
# |     word|count|
# +---------+-----+
# |bookshelf|    1|
# |   harder|    4|
# |    still|   95|
# |   outfit|    2|
# |arguments|    2|
# |standards|    2|
# |     hope|   10|
# |    ruben|    5|
# |    trail|    2|
# |      ...|   24|
# |   bazaar|    2|
# |traveling|    3|
# |     some|   94|
# | tortured|    1|
# |  tresses|    1|
# |      art|    3|
# |     guts|    1|
# |   ambrin|    8|
# |  reddish|    1|
# | cautious|    1|
# +---------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 14
# -------------------------------------------
# +---------+-----+
# |     word|count|
# +---------+-----+
# |bookshelf|    1|
# |   harder|    4|
# |    still|  101|
# |   outfit|    2|
# |arguments|    2|
# |standards|    2|
# |     hope|   13|
# |   biting|    2|
# |    ruben|    5|
# |    trail|    2|
# |      ...|   25|
# |   bazaar|    2|
# |traveling|    3|
# |     some|  101|
# | tortured|    1|
# |  tresses|    1|
# |      art|    3|
# |     guts|    1|
# |   ambrin|    8|
# |  reddish|    1|
# +---------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 15
# -------------------------------------------
# +---------+-----+
# |     word|count|
# +---------+-----+
# |bookshelf|    1|
# |   harder|    4|
# |connected|    1|
# |    still|  114|
# |   outfit|    2|
# |arguments|    2|
# |standards|    2|
# |     hope|   14|
# |   biting|    2|
# |    ruben|    5|
# |    trail|    2|
# |      ...|   25|
# |   bazaar|    2|
# |traveling|    3|
# |     some|  108|
# | tortured|    1|
# |  tresses|    1|
# |      art|    3|
# |     guts|    1|
# |   ambrin|    8|
# +---------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 16
# -------------------------------------------
# +---------+-----+
# |     word|count|
# +---------+-----+
# |bookshelf|    1|
# |   harder|    4|
# |connected|    1|
# |    still|  122|
# |   outfit|    2|
# |arguments|    2|
# |standards|    2|
# |     hope|   14|
# |   biting|    2|
# |    ruben|    7|
# |    trail|    3|
# |      ...|   25|
# |   bazaar|    2|
# |traveling|    3|
# |     some|  117|
# | tortured|    1|
# |  tresses|    1|
# |      art|    3|
# |     guts|    1|
# |   ambrin|    8|
# +---------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 17
# -------------------------------------------
# +---------+-----+
# |     word|count|
# +---------+-----+
# |bookshelf|    1|
# |   harder|    4|
# |connected|    1|
# |    still|  136|
# |   outfit|    2|
# |arguments|    2|
# |standards|    2|
# |     hope|   16|
# |   biting|    2|
# |    ruben|   16|
# |    trail|    3|
# |      ...|   25|
# |   bazaar|    2|
# |traveling|    3|
# |     some|  124|
# | tortured|    2|
# |  tresses|    1|
# |      art|    3|
# |     guts|    1|
# |   ambrin|    8|
# +---------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 18
# -------------------------------------------
# +---------+-----+
# |     word|count|
# +---------+-----+
# |bookshelf|    1|
# |   harder|    5|
# |connected|    2|
# |    still|  148|
# |   outfit|    2|
# |arguments|    2|
# |standards|    2|
# |     hope|   16|
# |   biting|    2|
# |    ruben|   16|
# |    trail|    3|
# |      ...|   25|
# |   bazaar|    2|
# |traveling|    3|
# |     some|  127|
# | tortured|    2|
# |  tresses|    1|
# |      art|    3|
# |     guts|    1|
# |   ambrin|    8|
# +---------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 19
# -------------------------------------------
# +---------+-----+
# |     word|count|
# +---------+-----+
# |bookshelf|    1|
# |   harder|    5|
# |connected|    2|
# |    still|  153|
# |   outfit|    2|
# |arguments|    2|
# |standards|    2|
# |     hope|   16|
# |   biting|    3|
# |    ruben|   16|
# |    trail|    5|
# |      ...|   28|
# |   bazaar|    2|
# |traveling|    3|
# |     some|  129|
# | tortured|    2|
# |  tresses|    1|
# |      art|    3|
# |     guts|    1|
# |   ambrin|    8|
# +---------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# +----------------+-----+
# |            word|count|
# +----------------+-----+
# |       bookshelf|    1|
# |          waters|    1|
# |matter-of-factly|    1|
# |          harder|    5|
# |       connected|    2|
# |           still|  158|
# |          outfit|    2|
# |       arguments|    2|
# |       standards|    2|
# |            hope|   17|
# |          biting|    3|
# |           ruben|   16|
# |           trail|    5|
# |             ...|   28|
# |          bazaar|    2|
# |       traveling|    3|
# |            some|  136|
# |        tortured|    2|
# |         tresses|    1|
# |             art|    3|
# +----------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# +----------------+-----+
# |            word|count|
# +----------------+-----+
# |       bookshelf|    1|
# |          waters|    1|
# |matter-of-factly|    1|
# |          harder|    5|
# |       connected|    2|
# |           still|  172|
# |          outfit|    2|
# |       arguments|    2|
# |       standards|    2|
# |            hope|   17|
# |          biting|    3|
# |            pant|    1|
# |           ruben|   16|
# |           trail|    5|
# |             ...|   28|
# |          bazaar|    2|
# |       traveling|    3|
# |            some|  138|
# |        tortured|    3|
# |         tresses|    1|
# +----------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# +----------------+-----+
# |            word|count|
# +----------------+-----+
# |       bookshelf|    1|
# |          waters|    1|
# |matter-of-factly|    1|
# |          harder|    5|
# |       connected|    2|
# |           still|  181|
# |          outfit|    2|
# |       arguments|    2|
# |       standards|    2|
# |            hope|   17|
# |          biting|    3|
# |            pant|    1|
# |           ruben|   16|
# |           trail|    5|
# |             ...|   28|
# |          bazaar|    2|
# |       traveling|    4|
# |            some|  148|
# |        tortured|    3|
# |         tresses|    1|
# +----------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# +----------------+-----+
# |            word|count|
# +----------------+-----+
# |       bookshelf|    1|
# |          waters|    1|
# |matter-of-factly|    1|
# |          harder|    5|
# |       connected|    2|
# |           still|  187|
# |          outfit|    2|
# |       arguments|    2|
# |       standards|    2|
# |            hope|   17|
# |          biting|    3|
# |            pant|    1|
# |           ruben|   16|
# |           trail|    5|
# |             ...|   28|
# |          bazaar|    2|
# |       traveling|    4|
# |            some|  151|
# |        tortured|    3|
# |         tresses|    1|
# +----------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# +----------------+-----+
# |            word|count|
# +----------------+-----+
# |       bookshelf|    1|
# |          waters|    1|
# |matter-of-factly|    1|
# |          harder|    5|
# |       connected|    3|
# |           still|  193|
# |          outfit|    2|
# |       arguments|    2|
# |       standards|    2|
# |            hope|   17|
# |          biting|    4|
# |            pant|    1|
# |           ruben|   16|
# |           trail|    5|
# |             ...|   28|
# |          bazaar|    2|
# |       traveling|    4|
# |            some|  154|
# |        tortured|    4|
# |         tresses|    1|
# +----------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# +----------------+-----+
# |            word|count|
# +----------------+-----+
# |       bookshelf|    1|
# |          waters|    1|
# |matter-of-factly|    1|
# |          harder|    5|
# |       connected|    3|
# |           still|  202|
# |          outfit|    2|
# |       arguments|    2|
# |       standards|    2|
# |            hope|   17|
# |          biting|    4|
# |            pant|    1|
# |           ruben|   16|
# |           trail|    5|
# |             ...|   28|
# |          bazaar|    2|
# |       traveling|    4|
# |            some|  159|
# |      fermenting|    1|
# |        tortured|    4|
# +----------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# +----------------+-----+
# |            word|count|
# +----------------+-----+
# |       bookshelf|    1|
# |          waters|    1|
# |matter-of-factly|    1|
# |          harder|    5|
# |       connected|    4|
# |           still|  211|
# |          outfit|    2|
# |       arguments|    3|
# |       standards|    2|
# |            hope|   19|
# |          biting|    5|
# |            pant|    1|
# |           ruben|   16|
# |           trail|    5|
# |             ...|   29|
# |         barrier|    1|
# |          bazaar|    2|
# |       traveling|    4|
# |            some|  169|
# |      fermenting|    1|
# +----------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |      waters|    1|
# |      harder|    6|
# |       still|  213|
# |      outfit|    2|
# |   standards|    2|
# |      biting|    5|
# |        pant|    1|
# |       ruben|   16|
# |       trail|    5|
# |     barrier|    1|
# |        some|  174|
# |     tresses|    1|
# |        guts|    1|
# |      ambrin|   14|
# |shiny-reared|    1|
# |     jewelry|    2|
# |       those|   59|
# |     isbn-13|    1|
# |     flashed|   22|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 28
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |      waters|    1|
# |      harder|    6|
# |       still|  216|
# |      outfit|    2|
# |   standards|    2|
# |      biting|    6|
# |        pant|    1|
# |       ruben|   16|
# |       trail|    5|
# |     barrier|    1|
# |        some|  177|
# |     tresses|    1|
# |        guts|    1|
# |       inner|    1|
# |      ambrin|   14|
# |shiny-reared|    1|
# |     jewelry|    2|
# |       those|   63|
# |     isbn-13|    1|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 29
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |      waters|    1|
# |  electrical|    1|
# |      harder|    7|
# |       still|  226|
# |      outfit|    2|
# |   standards|    2|
# |      biting|    6|
# |        pant|    4|
# |       ruben|   16|
# |       trail|    6|
# |     barrier|    1|
# |        some|  183|
# |     tresses|    1|
# |        guts|    1|
# |       inner|    2|
# |      ambrin|   14|
# |shiny-reared|    1|
# |     jewelry|    2|
# |       those|   66|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 30
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |      waters|    1|
# |  electrical|    1|
# |      harder|    7|
# |       still|  234|
# |      outfit|    6|
# |   standards|    2|
# |      biting|    6|
# |        pant|    6|
# |       ruben|   16|
# |       trail|    6|
# |     barrier|    1|
# |        some|  185|
# |     tresses|    1|
# |        guts|    1|
# |       inner|    2|
# |      ambrin|   14|
# |shiny-reared|    1|
# |     jewelry|    2|
# |       those|   69|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 31
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |      waters|    2|
# |  electrical|    1|
# |       spoil|    3|
# |      harder|    7|
# |       still|  240|
# |      outfit|    6|
# |   standards|    2|
# |      biting|    6|
# |        pant|    6|
# |       ruben|   16|
# |       trail|    6|
# |     barrier|    1|
# |        some|  199|
# |     tresses|    1|
# |        guts|    2|
# |       inner|    2|
# |      ambrin|   14|
# |shiny-reared|    1|
# |     jewelry|    2|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 32
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |      waters|    2|
# |  electrical|    1|
# |       spoil|    3|
# |      harder|    7|
# |       still|  250|
# |      outfit|    6|
# |   standards|    3|
# |      biting|    6|
# |        pant|    6|
# |       ruben|   16|
# |       trail|    7|
# |     barrier|    1|
# |        some|  200|
# |     tresses|    1|
# |        guts|    2|
# |       inner|    3|
# |      ambrin|   14|
# |shiny-reared|    1|
# |     jewelry|    2|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 33
# -------------------------------------------
# +----------+-----+
# |      word|count|
# +----------+-----+
# | bookshelf|    1|
# |    waters|    2|
# |electrical|    1|
# |     spoil|    3|
# |    harder|    7|
# |     still|  256|
# |    outfit|    6|
# |  inverted|    2|
# | standards|    4|
# |    biting|    6|
# |      pant|    6|
# |     ruben|   16|
# |     trail|    7|
# |   barrier|    1|
# |      some|  205|
# |      iffy|    1|
# |   tresses|    1|
# |      guts|    2|
# |     inner|    3|
# |    ambrin|   14|
# +----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 34
# -------------------------------------------
# +----------+-----+
# |      word|count|
# +----------+-----+
# | bookshelf|    1|
# |    waters|    2|
# |electrical|    1|
# |     spoil|    3|
# |    harder|    8|
# |     still|  266|
# |    outfit|    6|
# |  inverted|    2|
# | standards|    4|
# |    biting|    6|
# |      pant|    6|
# |     ruben|   16|
# |     trail|    7|
# |   barrier|    1|
# |commanders|    4|
# |      some|  219|
# |      iffy|    1|
# |  shipyard|    1|
# |   tresses|    1|
# |   familia|    1|
# +----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 35
# -------------------------------------------
# +----------+-----+
# |      word|count|
# +----------+-----+
# | bookshelf|    1|
# |    waters|    2|
# |electrical|    1|
# |     spoil|    3|
# |    harder|    8|
# |     still|  269|
# |    outfit|    6|
# |  inverted|    2|
# | standards|    4|
# |    biting|    6|
# |      pant|    6|
# |     ruben|   16|
# |     trail|    8|
# |   barrier|    1|
# |commanders|    4|
# |      some|  224|
# |      iffy|    1|
# |  shipyard|    1|
# |   tresses|    1|
# |   familia|    1|
# +----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 36
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    3|
# | electrical|    1|
# |      spoil|    3|
# |     harder|    9|
# |      still|  271|
# |     outfit|    6|
# |   inverted|    2|
# |  standards|    4|
# |     biting|    6|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|    8|
# |    barrier|    1|
# | commanders|    4|
# |       some|  230|
# |       iffy|    1|
# |   shipyard|    1|
# |    tresses|    1|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 37
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    3|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   10|
# |      still|  275|
# |     outfit|    7|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    5|
# |     biting|    6|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|    8|
# |   antennae|    1|
# |    barrier|    2|
# | commanders|    4|
# |       some|  239|
# |       iffy|    1|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 38
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    3|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   10|
# |      still|  276|
# |     outfit|    7|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    6|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|    9|
# |   antennae|    1|
# |    barrier|    2|
# | commanders|    4|
# |       some|  246|
# |       iffy|    1|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 39
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   11|
# |      still|  283|
# |     outfit|    8|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    6|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|    9|
# |   antennae|    1|
# |    barrier|    2|
# | commanders|    4|
# |       some|  256|
# |       iffy|    1|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 40
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   11|
# |      still|  290|
# |     outfit|    9|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    6|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|    9|
# |   antennae|    1|
# |    barrier|    2|
# | commanders|    4|
# |       some|  266|
# |       iffy|    1|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 41
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   11|
# |      still|  291|
# |     outfit|    9|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    6|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|   10|
# |   antennae|    1|
# |    barrier|    2|
# | commanders|    4|
# |       some|  273|
# |       iffy|    1|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 42
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   11|
# |      still|  298|
# |     outfit|    9|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    6|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|   10|
# |   antennae|    1|
# |    barrier|    2|
# | commanders|    4|
# |       some|  284|
# |       iffy|    1|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 43
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   11|
# |      still|  299|
# |     outfit|    9|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    6|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|   11|
# |   antennae|    1|
# |    barrier|    2|
# | commanders|    4|
# |       some|  292|
# |       iffy|    1|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 44
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   11|
# |      still|  306|
# |     outfit|    9|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    6|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|   11|
# |   antennae|    1|
# |    barrier|    2|
# | commanders|    4|
# |       some|  294|
# |       iffy|    1|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 45
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   11|
# |      still|  316|
# |     outfit|    9|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    7|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|   15|
# |   antennae|    1|
# |    barrier|    2|
# |       cubs|    1|
# | commanders|    4|
# |       some|  299|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 46
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   15|
# |      still|  325|
# |     outfit|    9|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    7|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|   23|
# |   antennae|    1|
# |    barrier|    2|
# |       cubs|    3|
# | commanders|    4|
# |       some|  307|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 47
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   15|
# |      still|  328|
# |     outfit|    9|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    7|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|   32|
# |   antennae|    1|
# |    barrier|    2|
# |       cubs|    4|
# | commanders|    4|
# |       some|  310|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 48
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   15|
# |      still|  330|
# |     outfit|    9|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    7|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|   32|
# |   antennae|    1|
# |    barrier|    2|
# |       cubs|    4|
# | commanders|    4|
# |       some|  319|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 49
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   15|
# |      still|  332|
# |     outfit|    9|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    7|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|   38|
# |   antennae|    1|
# |    barrier|    2|
# |       cubs|    4|
# | commanders|    4|
# |       some|  324|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 50
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   16|
# |      still|  335|
# |     outfit|    9|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    7|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |      trail|   42|
# |   antennae|    1|
# |    barrier|    2|
# |       cubs|    4|
# | commanders|    4|
# |       some|  325|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 51
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   16|
# |      still|  340|
# |     outfit|    9|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    7|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |     puddly|    1|
# |      trail|   45|
# |   antennae|    1|
# |    barrier|    2|
# |       cubs|    4|
# | commanders|    4|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 52
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   17|
# |      still|  350|
# |     outfit|   10|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    7|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |     puddly|    1|
# |      trail|   45|
# |   antennae|    1|
# |    barrier|    2|
# |       cubs|    4|
# | commanders|    4|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 53
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   18|
# |      still|  358|
# |     outfit|   10|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    7|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |     puddly|    1|
# |      trail|   45|
# |   antennae|    1|
# |    barrier|    2|
# |       cubs|    4|
# | commanders|    4|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 54
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   20|
# |      still|  363|
# |     outfit|   10|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    7|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |     puddly|    1|
# |      trail|   45|
# |   antennae|    1|
# |    barrier|    2|
# |       cubs|    4|
# | commanders|    4|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 55
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   20|
# |      still|  371|
# |     outfit|   10|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    7|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |     puddly|    1|
# |      trail|   45|
# |   antennae|    1|
# |    barrier|    2|
# |       cubs|    4|
# | commanders|    4|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 56
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    1|
# |      spoil|    3|
# |     harder|   20|
# |      still|  374|
# |     outfit|   11|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    8|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |     puddly|    1|
# |      trail|   45|
# | creativity|    1|
# |   antennae|    1|
# |    barrier|    2|
# |       cubs|    4|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 57
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    4|
# |      spoil|    3|
# |     harder|   21|
# |      still|  384|
# |     outfit|   11|
# |   inverted|    2|
# |     gloria|    3|
# |  standards|    8|
# |     biting|    8|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |     puddly|    1|
# |      trail|   45|
# | creativity|    1|
# |   antennae|    1|
# |    barrier|    2|
# |       cubs|    4|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 58
# -------------------------------------------
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |  bookshelf|    1|
# |     waters|    5|
# | electrical|    4|
# |      spoil|    3|
# |     harder|   21|
# |      still|  398|
# |     outfit|   11|
# |   inverted|    2|
# |     gloria|    3|
# |   priority|    1|
# |  standards|    8|
# |     biting|    9|
# |transaction|    1|
# |       pant|    6|
# |      ruben|   16|
# |     puddly|    1|
# |      trail|   45|
# | creativity|    1|
# |   antennae|    1|
# |    barrier|    2|
# +-----------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 59
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    4|
# |    inverted|    2|
# |   standards|    8|
# |      biting|    9|
# |        pant|    6|
# |       ruben|   16|
# |       trail|   45|
# |        cubs|    4|
# |        some|  372|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  119|
# |     isbn-13|    1|
# |     embrace|    4|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 60
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    4|
# |    inverted|    2|
# |   standards|    8|
# |      biting|    9|
# |        pant|    6|
# |       ruben|   16|
# |       trail|   47|
# |        cubs|    4|
# |        some|  376|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  122|
# |     isbn-13|    1|
# |     embrace|    4|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 61
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    4|
# |    inverted|    2|
# |   standards|    8|
# |      biting|    9|
# |        pant|    6|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   47|
# |        cubs|    4|
# |        some|  380|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  125|
# |     isbn-13|    1|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 62
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    4|
# |    inverted|    2|
# |   standards|    8|
# |      biting|    9|
# |        pant|    6|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   47|
# |        cubs|    4|
# |        some|  387|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  125|
# |     isbn-13|    1|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 63
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    4|
# |    inverted|    2|
# |   standards|    8|
# |      biting|    9|
# |        pant|    6|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   49|
# |        cubs|    4|
# |        some|  401|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  128|
# |     isbn-13|    1|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 64
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    4|
# |   unworldly|    1|
# |    inverted|    2|
# |   standards|    8|
# |      biting|    9|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   49|
# |        cubs|    4|
# |        some|  411|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  133|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 65
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    4|
# |   unworldly|    1|
# |    inverted|    2|
# |   standards|    8|
# |      biting|    9|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   49|
# |        cubs|    4|
# |        some|  419|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  136|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 66
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    4|
# |   unworldly|    1|
# |    inverted|    2|
# |   standards|    8|
# |      biting|    9|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   50|
# |        cubs|    4|
# |        some|  434|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  139|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 67
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    4|
# |   unworldly|    1|
# |    inverted|    2|
# |   standards|    8|
# |      biting|    9|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   50|
# |        cubs|    4|
# |        some|  445|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  142|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 68
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    4|
# |   unworldly|    1|
# |    inverted|    2|
# |   standards|    8|
# |      biting|    9|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   50|
# |        cubs|    4|
# |        some|  452|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  149|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 69
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    4|
# |   unworldly|    1|
# |    inverted|    2|
# |   standards|    8|
# |      biting|    9|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   51|
# |        cubs|    4|
# |        some|  464|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  153|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 70
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    4|
# |   unworldly|    1|
# |    inverted|    2|
# |   standards|    8|
# |      biting|    9|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   51|
# |        cubs|    4|
# |        some|  469|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  155|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 71
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    5|
# |   unworldly|    1|
# |    inverted|    2|
# |   standards|    8|
# |      biting|    9|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   51|
# |        cubs|    4|
# |        some|  472|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  158|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 72
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    5|
# |   unworldly|    1|
# |    inverted|    2|
# |   standards|    8|
# |      biting|   10|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   51|
# |        cubs|    4|
# |        some|  480|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  160|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 73
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    5|
# |   unworldly|    1|
# |    inverted|    2|
# |   standards|    8|
# |      biting|   10|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   52|
# |        cubs|    4|
# |        some|  485|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  161|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 74
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    5|
# |   unworldly|    1|
# |    inverted|    2|
# |   standards|    8|
# |      biting|   10|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   53|
# |        cubs|    4|
# |        some|  495|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  164|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 75
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    5|
# |   unworldly|    1|
# |    inverted|    2|
# |   standards|    8|
# |      biting|   10|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   53|
# |        cubs|    4|
# |        some|  509|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    3|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# |       those|  165|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 76
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    5|
# |   unworldly|    1|
# |  paramedics|    1|
# |    inverted|    2|
# |   standards|    8|
# |      biting|   10|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   53|
# |        cubs|    4|
# |        some|  517|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    4|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# +------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 77
# -------------------------------------------
# +------------+-----+
# |        word|count|
# +------------+-----+
# |   bookshelf|    1|
# |  electrical|    5|
# |   unworldly|    1|
# |  paramedics|    2|
# |    inverted|    2|
# |   standards|    8|
# |      biting|   10|
# |        pant|    7|
# |       ruben|   16|
# |     courted|    1|
# |       trail|   53|
# |        cubs|    4|
# |        some|  530|
# |    shipyard|    1|
# |     tresses|    1|
# |     familia|    1|
# |        guts|    4|
# |      coaxed|    1|
# |shiny-reared|    1|
# |     jewelry|    3|
# +------------+-----+
# ...
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2646
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  211|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2647
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  211|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2648
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  211|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2649
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  211|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2650
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  211|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2651
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  211|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2652
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  211|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2653
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  211|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2654
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  211|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2655
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  211|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2656
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  211|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2657
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  211|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2658
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  212|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2659
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  212|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2660
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  213|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2661
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  214|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2662
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  214|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2663
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  214|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
# -------------------------------------------
# Batch: 2664
# -------------------------------------------
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |           bookshelf|   60|
# |          electrical|  215|
# |          boudreauxs|    2|
# |           grimoires|   10|
# |            crawlies|    1|
# |             pringle|   26|
# |            un-human|    1|
# |          knife-work|    3|
# |         combatively|    2|
# |             thingee|    1|
# |            inimical|    2|
# |            ryopyaku|    1|
# |nutter-who-rowed-...|    1|
# |            inverted|   50|
# |                bava|   64|
# |                pant|   68|
# |           six-month|    5|
# |             heeling|    3|
# |          creakingly|    1|
# |        invalidating|    3|
# +--------------------+-----+
# only showing top 20 rows
